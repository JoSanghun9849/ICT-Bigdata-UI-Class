# %%
year = int(input("연도를 입력하세요 : "))


if year < 1918:
    if year%4==0:
        print("%d년-09-%d"%(year,257-243),sep = "")
    else:
        print("%d년-09-%d"%(year,256-243),sep = "")
elif year==1918:
    
    print("%d년-09-%d"%(year,256-230),sep = "")
elif year <2701:
    if year%400==0:
        print("%d년-09-%d"%(year,257-243),sep = "")
    elif year%100==0:
        print("%d년-09-%d"%(year,256-243),sep = "")
    elif year%4==0:
        print("%d년-09-%d"%(year,257-243),sep = "")
    else:
        print("%d년-09-%d"%(year,256-243),sep = "")
else:
    print("범위를 벗어났습니다.")
# Out:
# 연도를 입력하세요 : 1918
# 1918년-09-26

# %%
num = input("우편번호 : ")
postNo = num[:3]
if postNo in ["010","011","012"]:
    print("강북구")
elif postNo in["013","014","015"]:
    print("도봉구")
elif postNo in["016","017","018","019"]:
    print("노원구")
# Out:
# 우편번호 : 01400
# 도봉구

# %%
f = open("ex.txt",'r')
str= f.readlines()
f.close()

print(str)
print(str[0].count("on"))
print(str[0].replace("python","PYTHON"))


a = "hello"

b= a.maketrans("llo","zzz")
a.translate(b)

a = str[0].split()
len(a)
# Out:
# ['Documentation for python is standard library along with tutorials and guides are available online']
# 4
# Documentation for PYTHON is standard library along with tutorials and guides are available online
# 14

# %%
f = open("number.txt",'r')
a = f.readlines()
f.close()
b=a[0].split()
print(b)

sum=0
for i in b:
    sum=sum+int(i)
print(sum)
# Out:
# ['10', '20', '30', '15', '24', '65', '28', '32', '56', '47', '22', '30', '24', '65', '84', '22', '14']
# 588

# %%
a = open("text.txt",'r')

b = a.readlines()
a.close()
print(b)
# Out:
# ['information communication technologies polytec college']

# %%
tuy = open("temp.txt",'r')
wit = tuy.readlines()
tuy.close()

print(wit)
print(wit[0].split())
# Out:
# ['information communication technologies polytec college How are you']
# ['information', 'communication', 'technologies', 'polytec', 'college', 'How', 'are', 'you']

# %%
a = open("python.txt",'w')
a.write("Hello Python")
a.close()
